# %%
import pandas as pd
df = pd.read_csv("spam_assassin_dataset.csv")

# %%
rows, columns = df.shape
print("Number of records:", rows)
print("Number of features:", columns)
df.size

# %%
df.head()

# %%
df.info()

# %%
df.isnull().sum()
